# %% [markdown]
# # 2-wymiarowy rozkład Normalny

# %%
import matplotlib.pyplot as plt
import numpy as np
import numpy.random as rnd
import scipy.stats as stats
from scipy.stats import multivariate_normal

# %% [markdown]
# # Zadanie
# Proszę wygenerować próbkę z rozkładu Normalnego
# $$
# m = [0,0]
# $$
#
# oraz
#
# $$
# \Sigma = [[4.40, -2.75], [-2.75,  5.50]]
# $$

# %%
mean1 = np.array([0, 0])
cov1 = np.array([[4.40, -2.75], [-2.75,  5.50]])
X1_rv=multivariate_normal(mean1, cov1)
X = X1_rv.rvs(1000)

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(5, 5))
ax.scatter(X[:, 0], X[:, 1])
ax.set_xlim([-10,10])
ax.set_ylim([-10,10])
plt.show()

# %% [markdown]
# # Zadanie
# Proszę policzyć średnią oraz macierz kowariancji próbki.

# %%
means = X.mean(axis=0)
cov = np.cov(X.T)
print("means:\n", means)
print("cov:\n", cov)
# Out:
# means:
#  [ 0.04472957 -0.00379265]
# cov:
#  [[ 4.71260687 -3.13776439]
#  [-3.13776439  5.44913995]]

# %% [markdown]
# # Zadanie
# Proszę zdefiniować zmienną losową o razkładzie zadanym na podstawie empirycznej średniej i kowariancji oraz narysować na jednym wykresie:
#
# - próbkę
# - poziomice rozkładu normalnego

# %%
X2_rv = multivariate_normal(means, cov)
X = X2_rv.rvs(1000)

# %%
x, y = np.meshgrid(np.linspace(-10, 10, 500), np.linspace(-10, 10, 500))
pos = np.dstack((x, y))
z = X2_rv.pdf(pos)

fig, ax = plt.subplots(1,1, figsize=(6, 6))
ax.scatter(X[:, 0], X[:, 1], alpha=0.8)
plt.contour(x, y, z, colors='r');

# %% [markdown]
# # Zadanie
# Policz wektory i wartości własne macierzy kowariancji. Narysuj na jednym wykresie
#
# - próbkę
# - poziomice rozkładu normalnego
# - wektory własne macierzy kowariancji

# %%
X = X2_rv.rvs(1000)

x, y = np.meshgrid(np.linspace(-10, 10, 500), np.linspace(-10, 10, 500))
pos = np.dstack((x, y))
z = X2_rv.pdf(pos)

origin = [0, 0]
eigen_values, eigen_vectors = np.linalg.eig(cov)
print('eigen_values: ', eigen_values)
print('eigen_vectors: ', eigen_vectors)
eig_vec1 = eigen_vectors[:,0]
eig_vec2 = eigen_vectors[:,1]

fig, ax = plt.subplots(1,1, figsize=(6, 6))
ax.scatter(X[:, 0], X[:, 1], alpha=0.8)
plt.contour(x, y, z, colors='r')
plt.quiver(*origin, *eig_vec1*0.5, color=['k'], scale=1)
plt.quiver(*origin, *eig_vec2*0.5, color=['b'], scale=1)
# Out:
# eigen_values:  [1.92157196 8.24017486]
# eigen_vectors:  [[-0.74718332  0.66461801]
#  [-0.66461801 -0.74718332]]

# %% [markdown]
# # Zadanie
# Proszę wygenerować próbkę na kwadracie $[0,1] \times [0,1]$.
# Następnie proszę policzyć średnią oraz macierz kowariancji próbki.
#
# Narysuj na jednym wykresie
#
# - próbkę
# - poziomice rozkładu normalnego
# - wektory własne macierzy kowariancji

# %%
X = np.random.rand(1000, 2)
mean = np.mean(X, axis=0)
cov = np.cov(X.T)
print("means:\n", means)
print("cov:\n", cov)
# Out:
# means:
#  [ 0.04472957 -0.00379265]
# cov:
#  [[0.08310141 0.00208959]
#  [0.00208959 0.08248013]]

# %%
x, y = np.meshgrid(np.linspace(0, 1, 500), np.linspace(0, 1, 500))
pos = np.dstack((x, y))
X3_rv = multivariate_normal(mean, cov)
z = X3_rv.pdf(pos)

origin = [0.5, 0.5]
eigen_values, eigen_vectors = np.linalg.eig(cov)
print('eigen_values: ', eigen_values)
print('eigen_vectors: ', eigen_vectors)
eig_vec1 = eigen_vectors[:,0]
eig_vec2 = eigen_vectors[:,1]

fig, ax = plt.subplots(1,1, figsize=(6, 6))
ax.scatter(X[:, 0], X[:, 1], alpha=0.8)
plt.contour(x, y, z, colors='r')
plt.quiver(*origin, *eig_vec1, color=['r'])
plt.quiver(*origin, *eig_vec2, color=['r'])
plt.xlim([-0.5, 1.5])
plt.ylim([-0.5, 1.5])
# Out:
# eigen_values:  [0.08490332 0.08067822]
# eigen_vectors:  [[ 0.75731281 -0.6530523 ]
#  [ 0.6530523   0.75731281]]
# (-0.5, 1.5)
