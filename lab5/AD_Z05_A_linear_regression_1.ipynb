# %% [markdown]
# # Regresja liniowa

# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import sklearn.linear_model as lm
import matplotlib.pyplot as plt

# %% [markdown]
# Proszę narysować wykres dowolnej funkcji na odcinku $[0,3]$.
#
# Będzie to model, który będziemy chcieli znaleźć.

# %%
f = lambda x: ((x*2-1)*(x**2-2)*(x-2)+3)
x_tr = np.linspace(0, 3, 200)
y_tr = f(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_tr[:200], y_tr[:200], '--k');
plt.show()

# %% [markdown]
# Proszę wylosować kilka punktów z otoczenia funkcji $f(x)$.
#
# Na ich podstawie będziemy wykonywać naszej presykcji.

# %%
x = stats.uniform(0,3).rvs(100)
y = f(x) + stats.norm(0,0.2).rvs(len(x))
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_tr, y_tr, '--k');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# Nauczmy prosty model regresji liniowej
#
# $$
# y=a\cdot x + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.
# My narazie urzyjemy metody opartej na rozwiązaniu układu równań liniowych.

# %%
M1 = np.vstack( (np.ones_like(x), x) ).T
p1 = np.linalg.lstsq(M1, y, rcond=None)

# %% [markdown]
# Definiujemy naszą funkcję regresji

# %%
f_lr_1 = lambda x: p1[0][1] * x +p1[0][0]

# %%
x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_1(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr, y_f_lr, 'g');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
M2 = np.vstack( (np.ones_like(x), x, x**2) ).T
p2 = np.linalg.lstsq(M2, y, rcond=None)

# %%
p2
# Out:
# (array([  8.54945188, -15.24426058,   6.97570187]),
#  array([1343.4816146]),
#  3,
#  array([46.61389864,  6.91326137,  1.54008895]))

# %% [markdown]
# Definiujemy naszą funkcję regresji

# %%
f_lr_2 = lambda x: p2[0][2]*pow(x,2) + p2[0][1] * x + p2[0][0]

# %%
x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_2(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr, y_f_lr, 'g');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + a_3 \cdot x ^3 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
M3 = np.vstack( (np.ones_like(x), x, x**2, x**3) ).T
p3 = np.linalg.lstsq(M3, y, rcond=None)

# %%
f_lr_3 = lambda x: p3[0][3]*pow(x,3) + p3[0][2]*pow(x,2) + p3[0][1] * x + p3[0][0]

# %%
x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_3(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr, y_f_lr, 'g');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + a_3 \cdot x ^3 + a_4 \cdot x ^4 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
M4 = np.vstack( (np.ones_like(x), x, x**2, x**3, x**4) ).T
p4 = np.linalg.lstsq(M4, y, rcond=None)

# %%
f_lr_4 = lambda x: p4[0][4]*pow(x,4) + p4[0][3]*pow(x,3) + p4[0][2]*pow(x,2) + p4[0][1] * x + p4[0][0]

# %%
x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_4(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr, y_f_lr, 'g');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + a_3 \cdot x ^3 + a_4 \cdot x ^4 + a_5 \cdot x^5 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
M5 = np.vstack( (np.ones_like(x), x, x**2, x**3, x**4, x**5) ).T
p5 = np.linalg.lstsq(M5, y, rcond=None)

# %%
f_lr_5 = lambda x: p5[0][5]*pow(x,5) + p5[0][4]*pow(x,4) + p5[0][3]*pow(x,3) + p5[0][2]*pow(x,2) + p5[0][1] * x + p5[0][0]

# %%
x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_5(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr, y_f_lr, 'g');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# # Zadanie
# Narysuj wszystkie wyniki na jednym wykresie.
#
# ## Która z krzywych jest najleprza?

# %%
x_f_lr = np.linspace(0., 3, 200)
y_f_lr1 = f_lr_1(x_tr)
y_f_lr2 = f_lr_2(x_tr)
y_f_lr3 = f_lr_3(x_tr)
y_f_lr4 = f_lr_4(x_tr)
y_f_lr5 = f_lr_5(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr, y_f_lr1, label='x');
plt.plot(x_f_lr, y_f_lr2, label='x^2');
plt.plot(x_f_lr, y_f_lr3, label='x^3');
plt.plot(x_f_lr, y_f_lr4, label='x^4');
plt.plot(x_f_lr, y_f_lr5, label='x^5');
plt.plot(x, y, 'ok', ms=10);
plt.legend()
plt.show()

# %% [markdown]
# # Zadanie
# Musimy mieć jakąś miarę oceny.

# %%
import statsmodels.api as sm
Res1 = sm.OLS(y, M1).fit()
Res2 = sm.OLS(y, M2).fit()
Res3 = sm.OLS(y, M3).fit()
Res4 = sm.OLS(y, M4).fit()
Res5 = sm.OLS(y, M5).fit()

# %%
print(Res1.summary2())
print(".....................................")
print(".....................................")
print(".....................................")
print(Res2.summary2())
print(".....................................")
print(".....................................")
print(".....................................")
print(Res3.summary2())
print(".....................................")
print(".....................................")
print(".....................................")
print(Res4.summary2())
print(".....................................")
print(".....................................")
print(".....................................")
print(Res5.summary2())
# Out:
#                  Results: Ordinary least squares
# =================================================================
# Model:              OLS              Adj. R-squared:     0.474
# Dependent Variable: y                AIC:                630.6795
# Date:               2024-04-06 11:46 BIC:                635.8899
# No. Observations:   100              Log-Likelihood:     -313.34
# Df Model:           1                F-statistic:        90.37
# Df Residuals:       98               Prob (F-statistic): 1.43e-15
# R-squared:          0.480            Scale:              31.473
# -------------------------------------------------------------------
#            Coef.    Std.Err.      t      P>|t|     [0.025    0.975]
# -------------------------------------------------------------------
# const     -3.4510     1.2291   -2.8077   0.0060   -5.8902   -1.0119
# x1         6.4274     0.6761    9.5064   0.0000    5.0857    7.7691
# -----------------------------------------------------------------
# Omnibus:              36.512       Durbin-Watson:          2.002
# Prob(Omnibus):        0.000        Jarque-Bera (JB):       71.119
# Skew:                 1.478        Prob(JB):               0.000
# Kurtosis:             5.886        Condition No.:          5
# =================================================================
#
# .....................................
# .....................................
# .....................................
#                  Results: Ordinary least squares
# =================================================================
# Model:              OLS              Adj. R-squared:     0.769
# Dependent Variable: y                AIC:                549.5727
# Date:               2024-04-06 11:46 BIC:                557.3882
# No. Observations:   100              Log-Likelihood:     -271.79
# Df Model:           2                F-statistic:        165.5
# Df Residuals:       97               Prob (F-statistic): 5.38e-32
# R-squared:          0.773            Scale:              13.850
# ------------------------------------------------------------------
#             Coef.    Std.Err.     t     P>|t|    [0.025    0.975]
# ------------------------------------------------------------------
# const        8.5495    1.3456   6.3537  0.0000    5.8788   11.2201
# x1         -15.2443    1.9844  -7.6821  0.0000  -19.1827  -11.3058
# x2           6.9757    0.6222  11.2111  0.0000    5.7408    8.2106
# -----------------------------------------------------------------
# Omnibus:              3.657        Durbin-Watson:           2.281
# Prob(Omnibus):        0.161        Jarque-Bera (JB):        3.033
# Skew:                 0.402        Prob(JB):                0.219
# Kurtosis:             3.288        Condition No.:           30
# =================================================================
#
# .....................................
# .....................................
# .....................................
#                  Results: Ordinary least squares
# =================================================================
# Model:              OLS              Adj. R-squared:     0.989
# Dependent Variable: y                AIC:                242.5025
# Date:               2024-04-06 11:46 BIC:                252.9232
# No. Observations:   100              Log-Likelihood:     -117.25
# Df Model:           3                F-statistic:        3074.
# Df Residuals:       96               Prob (F-statistic): 3.30e-95
# R-squared:          0.990            Scale:              0.63634
# ------------------------------------------------------------------
#            Coef.    Std.Err.     t      P>|t|    [0.025    0.975]
# ------------------------------------------------------------------
# const      -3.6380    0.3961   -9.1847  0.0000   -4.4242   -2.8517
# x1         26.1946    1.0164   25.7728  0.0000   24.1771   28.2121
# x2        -25.8044    0.7423  -34.7637  0.0000  -27.2779  -24.3310
# x3          7.1471    0.1592   44.8919  0.0000    6.8310    7.4631
# -----------------------------------------------------------------
# Omnibus:              7.045        Durbin-Watson:           1.940
# Prob(Omnibus):        0.030        Jarque-Bera (JB):        7.197
# Skew:                 0.656        Prob(JB):                0.027
# Kurtosis:             2.937        Condition No.:           189
# =================================================================
#
# .....................................
# .....................................
# .....................................
#                  Results: Ordinary least squares
# ==================================================================
# Model:              OLS              Adj. R-squared:     0.999
# Dependent Variable: y                AIC:                -28.4937
# Date:               2024-04-06 11:46 BIC:                -15.4678
# No. Observations:   100              Log-Likelihood:     19.247
# Df Model:           4                F-statistic:        3.532e+04
# Df Residuals:       95               Prob (F-statistic): 9.70e-150
# R-squared:          0.999            Scale:              0.041940
# --------------------------------------------------------------------
#            Coef.    Std.Err.      t       P>|t|     [0.025    0.975]
# --------------------------------------------------------------------
# const     -0.9700     0.1248    -7.7744   0.0000   -1.2177   -0.7223
# x1         9.9995     0.5106    19.5837   0.0000    8.9858   11.0131
# x2        -2.2544     0.6661    -3.3846   0.0010   -3.5767   -0.9321
# x3        -4.8081     0.3266   -14.7235   0.0000   -5.4564   -4.1598
# x4         1.9625     0.0532    36.8994   0.0000    1.8570    2.0681
# ------------------------------------------------------------------
# Omnibus:              1.408         Durbin-Watson:           2.090
# Prob(Omnibus):        0.495         Jarque-Bera (JB):        1.453
# Skew:                 -0.270        Prob(JB):                0.483
# Kurtosis:             2.761         Condition No.:           1315
# ==================================================================
# * The condition number is large (1e+03). This might indicate
# strong multicollinearity or other numerical problems.
# .....................................
# .....................................
# .....................................
#                  Results: Ordinary least squares
# ==================================================================
# Model:              OLS              Adj. R-squared:     0.999
# Dependent Variable: y                AIC:                -27.1220
# Date:               2024-04-06 11:46 BIC:                -11.4909
# No. Observations:   100              Log-Likelihood:     19.561
# Df Model:           5                F-statistic:        2.813e+04
# Df Residuals:       94               Prob (F-statistic): 1.45e-147
# R-squared:          0.999            Scale:              0.042120
# --------------------------------------------------------------------
#             Coef.    Std.Err.      t      P>|t|     [0.025    0.975]
# --------------------------------------------------------------------
# const      -0.9079     0.1488   -6.1018   0.0000   -1.2034   -0.6125
# x1          9.3853     0.9479    9.9016   0.0000    7.5033   11.2673
# x2         -0.8605     1.9300   -0.4459   0.6567   -4.6925    2.9715
# x3         -6.0194     1.6074   -3.7449   0.0003   -9.2109   -2.8280
# x4          2.4086     0.5820    4.1386   0.0001    1.2531    3.5642
# x5         -0.0586     0.0761   -0.7697   0.4434   -0.2098    0.0926
# ------------------------------------------------------------------
# Omnibus:              1.136         Durbin-Watson:           2.064
# Prob(Omnibus):        0.567         Jarque-Bera (JB):        1.191
# Skew:                 -0.242        Prob(JB):                0.551
# Kurtosis:             2.775         Condition No.:           10625
# ==================================================================
# * The condition number is large (1e+04). This might indicate
# strong multicollinearity or other numerical problems.

# %% [markdown]
# # Zadanie
# Analogiczne wyniki możemy izusklać za pomocą prostego kodu.

# %%
import statsmodels.formula.api as smf
# Turn the data into a pandas DataFrame, so that we
# can address them in the formulas with their name
df = pd.DataFrame({'x':x, 'y':y})

# Fit the models, and show the results
Res1F = smf.ols('y~x', df).fit()
Res2F = smf.ols('y ~ x+I(x**2)', df).fit()

# %%
print(Res1F.summary())
print(".....................................")
print(".....................................")
print(".....................................")
print(Res2F.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.480
# Model:                            OLS   Adj. R-squared:                  0.474
# Method:                 Least Squares   F-statistic:                     90.37
# Date:                Sat, 06 Apr 2024   Prob (F-statistic):           1.43e-15
# Time:                        11:44:24   Log-Likelihood:                -313.34
# No. Observations:                 100   AIC:                             630.7
# Df Residuals:                      98   BIC:                             635.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -3.4510      1.229     -2.808      0.006      -5.890      -1.012
# x              6.4274      0.676      9.506      0.000       5.086       7.769
# ==============================================================================
# Omnibus:                       36.512   Durbin-Watson:                   2.002
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               71.119
# Skew:                           1.478   Prob(JB):                     3.60e-16
# Kurtosis:                       5.886   Cond. No.                         4.99
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# .....................................
# .....................................
# .....................................
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.773
# Model:                            OLS   Adj. R-squared:                  0.769
# Method:                 Least Squares   F-statistic:                     165.5
# Date:                Sat, 06 Apr 2024   Prob (F-statistic):           5.38e-32
# Time:                        11:44:24   Log-Likelihood:                -271.79
# No. Observations:                 100   AIC:                             549.6
# Df Residuals:                      97   BIC:                             557.4
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      8.5495      1.346      6.354      0.000       5.879      11.220
# x            -15.2443      1.984     -7.682      0.000     -19.183     -11.306
# I(x ** 2)      6.9757      0.622     11.211      0.000       5.741       8.211
# ==============================================================================
# Omnibus:                        3.657   Durbin-Watson:                   2.281
# Prob(Omnibus):                  0.161   Jarque-Bera (JB):                3.033
# Skew:                           0.402   Prob(JB):                        0.219
# Kurtosis:                       3.288   Cond. No.                         30.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
