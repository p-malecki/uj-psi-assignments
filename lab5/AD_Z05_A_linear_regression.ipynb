# %% [markdown]
# # Regresja liniowa

# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import sklearn.linear_model as lm
import matplotlib.pyplot as plt

# %% [markdown]
# Proszę narysować wykres dowolnej funkcji na odcinku $[0,3]$.
#
# Będzie to model, który będziemy chcieli znaleźć.

# %%
f = lambda x: ((x*2-1)*(x**2-2)*(x-2)+3)
x_tr = np.linspace(0, 3, 200)
y_tr = f(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_tr[:200], y_tr[:200], '--k');
plt.show()

# %% [markdown]
# Proszę wylosować kilka punktów z otoczenia funkcji $f(x)$.
#
# Na ich podstawie będziemy wykonywać naszej presykcji.

# %%
x = stats.uniform(0,3).rvs(100)
y = f(x) + stats.norm(0,0.2).rvs(len(x))
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_tr, y_tr, '--k');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# Nauczmy prosty model regresji liniowej
#
# $$
# y=a\cdot x + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.
# My narazie urzyjemy metody opartej na rozwiązaniu układu równań liniowych.

# %%
M1 = np.vstack( (np.ones_like(x), x) ).T
p1 = np.linalg.lstsq(M1, y, rcond=None)

# %% [markdown]
# Definiujemy naszą funkcję regresji

# %%
f_lr_1 = lambda x: p1[0][1] * x + p1[0][0]

# %%
x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_1(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr, y_f_lr, 'g');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
M2 = np.vstack( (np.ones_like(x), x, x**2) ).T
p2 = np.linalg.lstsq(M2, y, rcond=None)

# %% [markdown]
# Definiujemy naszą funkcję regresji

# %%
f_lr_2 = lambda x: p2[0][2]*pow(x,2) + p2[0][1] * x + p2[0][0]

# %%
x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_2(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr, y_f_lr, 'g');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + a_3 \cdot x ^3 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
M3 = np.vstack( (np.ones_like(x), x, x**2, x**3) ).T
p3 = np.linalg.lstsq(M3, y, rcond=None)

f_lr_3 = lambda x: p3[0][3]*pow(x,3) + p3[0][2]*pow(x,2) + p3[0][1]*x + p3[0][0]

# %%
x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_3(x_f_lr)
plt.figure(figsize=(6,6))
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
axes.plot(x_f_lr, y_f_lr, 'g')
axes.plot(x, y, 'ok', ms=10);

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + a_3 \cdot x ^3 + a_4 \cdot x ^4 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
M4 = np.vstack( (np.ones_like(x), x, x**2, x**3, x**4) ).T
p4 = np.linalg.lstsq(M4, y, rcond=None)

f_lr_4 = lambda x: p4[0][4]*pow(x,4) + p4[0][3]*pow(x,3) + p4[0][2]*pow(x,2) + p4[0][1]*x + p4[0][0]

# %%
x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_4(x_f_lr)
plt.figure(figsize=(6,6))
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
axes.plot(x_f_lr, y_f_lr, 'g')
axes.plot(x, y, 'ok', ms=10);

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + a_3 \cdot x ^3 + a_4 \cdot x ^4 + a_5 \cdot x^5 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
M5 = np.vstack( (np.ones_like(x), x, x**2, x**3, x**4, x**5) ).T
p5 = np.linalg.lstsq(M5, y, rcond=None)

f_lr_5 = lambda x: p5[0][5]*pow(x,5) + p5[0][4]*pow(x,4) + p5[0][3]*pow(x,3) + p5[0][2]*pow(x,2) + p5[0][1]*x + p5[0][0]

# %%
x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_5(x_f_lr)
plt.figure(figsize=(6,6))
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
axes.plot(x_f_lr, y_f_lr, 'g')
axes.plot(x, y, 'ok', ms=10);

# %% [markdown]
# # Zadanie
# Narysuj wszystkie wyniki na jednym wykresie.
#
# ## Która z krzywych jest najleprza?

# %%
fig, axes = plt.subplots(1, 5, figsize=((20,5)))
x_f_lr = np.linspace(0., 3, 200)
f_lrs = [f_lr_1, f_lr_2, f_lr_3, f_lr_4, f_lr_5]
for i in range(5):
    y_f_lr = f_lrs[i](x_f_lr)
    axes[i].set_xlim([0,3])
    axes[i].set_ylim([0,8])
    axes[i].plot(x_f_lr, y_f_lr, 'g')
    axes[i].plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# # Zadanie
# Musimy mieć jakąś miarę oceny.

# %%
import statsmodels.api as sm
Res1 = sm.OLS(y, M1).fit()
Res2 = sm.OLS(y, M2).fit()

# %%
print(Res1.summary2())
print(".....................................")
print(".....................................")
print(".....................................")
print(Res2.summary2())
# Out:
#                  Results: Ordinary least squares
# =================================================================
# Model:              OLS              Adj. R-squared:     0.458
# Dependent Variable: y                AIC:                644.1733
# Date:               2024-04-10 00:48 BIC:                649.3837
# No. Observations:   100              Log-Likelihood:     -320.09
# Df Model:           1                F-statistic:        84.59
# Df Residuals:       98               Prob (F-statistic): 6.69e-15
# R-squared:          0.463            Scale:              36.019
# -------------------------------------------------------------------
#            Coef.    Std.Err.      t      P>|t|     [0.025    0.975]
# -------------------------------------------------------------------
# const     -3.0742     1.2190   -2.5220   0.0133   -5.4932   -0.6553
# x1         6.3464     0.6900    9.1971   0.0000    4.9770    7.7157
# -----------------------------------------------------------------
# Omnibus:              31.172       Durbin-Watson:          2.355
# Prob(Omnibus):        0.000        Jarque-Bera (JB):       51.635
# Skew:                 1.356        Prob(JB):               0.000
# Kurtosis:             5.244        Condition No.:          5
# =================================================================
# Notes:
# [1] Standard Errors assume that the covariance matrix of the
# errors is correctly specified.
# .....................................
# .....................................
# .....................................
#                  Results: Ordinary least squares
# =================================================================
# Model:              OLS              Adj. R-squared:     0.794
# Dependent Variable: y                AIC:                548.2343
# Date:               2024-04-10 00:48 BIC:                556.0498
# No. Observations:   100              Log-Likelihood:     -271.12
# Df Model:           2                F-statistic:        192.1
# Df Residuals:       97               Prob (F-statistic): 1.84e-34
# R-squared:          0.798            Scale:              13.666
# ------------------------------------------------------------------
#             Coef.    Std.Err.     t     P>|t|    [0.025    0.975]
# ------------------------------------------------------------------
# const        8.0153    1.1516   6.9601  0.0000    5.7296   10.3009
# x1         -15.9691    1.8078  -8.8336  0.0000  -19.5571  -12.3812
# x2           7.4416    0.5859  12.7002  0.0000    6.2787    8.6046
# -----------------------------------------------------------------
# Omnibus:              1.382        Durbin-Watson:           2.162
# Prob(Omnibus):        0.501        Jarque-Bera (JB):        1.448
# Skew:                 0.260        Prob(JB):                0.485
# Kurtosis:             2.723        Condition No.:           26
# =================================================================
# Notes:
# [1] Standard Errors assume that the covariance matrix of the
# errors is correctly specified.

# %% [markdown]
# # Zadanie
# Analogiczne wyniki możemy izusklać za pomocą prostego kodu.

# %%
import statsmodels.formula.api as smf
# Turn the data into a pandas DataFrame, so that we
# can address them in the formulas with their name
df = pd.DataFrame({'x':x, 'y':y})

# Fit the models, and show the results
Res1F = smf.ols('y~x', df).fit()
Res2F = smf.ols('y ~ x+I(x**2)', df).fit()

# %%
print(Res1F.summary())
print(".....................................")
print(".....................................")
print(".....................................")
print(Res2F.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.487
# Model:                            OLS   Adj. R-squared:                  0.482
# Method:                 Least Squares   F-statistic:                     93.14
# Date:                Sun, 07 May 2017   Prob (F-statistic):           6.93e-16
# Time:                        09:57:02   Log-Likelihood:                -303.57
# No. Observations:                 100   AIC:                             611.1
# Df Residuals:                      98   BIC:                             616.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     -2.6934      1.009     -2.669      0.009        -4.696    -0.691
# x              6.0015      0.622      9.651      0.000         4.767     7.236
# ==============================================================================
# Omnibus:                       38.537   Durbin-Watson:                   2.247
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               95.249
# Skew:                           1.413   Prob(JB):                     2.07e-21
# Kurtosis:                       6.857   Cond. No.                         4.20
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# .....................................
# .....................................
# .....................................
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.763
# Model:                            OLS   Adj. R-squared:                  0.758
# Method:                 Least Squares   F-statistic:                     156.2
# Date:                Sun, 07 May 2017   Prob (F-statistic):           4.72e-31
# Time:                        09:57:02   Log-Likelihood:                -264.98
# No. Observations:                 100   AIC:                             536.0
# Df Residuals:                      97   BIC:                             543.8
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      5.6426      1.045      5.402      0.000         3.569     7.716
# x            -10.5600      1.616     -6.535      0.000       -13.767    -7.353
# I(x ** 2)      5.6480      0.532     10.623      0.000         4.593     6.703
# ==============================================================================
# Omnibus:                        5.962   Durbin-Watson:                   2.070
# Prob(Omnibus):                  0.051   Jarque-Bera (JB):                5.995
# Skew:                           0.390   Prob(JB):                       0.0499
# Kurtosis:                       3.911   Cond. No.                         22.4
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
